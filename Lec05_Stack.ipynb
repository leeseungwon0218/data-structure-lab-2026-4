# %% [markdown]
# # Lecture 05: Basic Data Structure: Stacks

# %% [markdown]
# ## 1. Stack Class

# %%
class Stack:
     def __init__(self):
         self.items = []

     def is_empty(self):
         return self.items == []

     def push(self, item):
         self.items.append(item)

     def pop(self):
         return self.items.pop()

     def peek(self):
         return self.items[len(self.items)-1]

     def size(self):
         return len(self.items)

     def pop_all(self):
          self.items.clear()

# %%
s = Stack()

# %%
print(s.is_empty())
# Out:
# True

# %%
s.push(4)

# %%
s.push('dog')

# %%
print(s.peek())
# Out:
# dog

# %%
s.push(True)

# %%
print(s.size())
# Out:
# 3

# %%
print(s.is_empty())
# Out:
# False

# %%
s.push(8.4)

# %%
print(s.pop())
# Out:
# 8.4

# %%
print(s.pop())
# Out:
# True

# %%
print(s.size())
# Out:
# 2

# %%
s.pop_all
# Out:
# <bound method Stack.pop_all of <__main__.Stack object at 0x7f3ac8cb9970>>

# %%
print(s)
# Out:
# <__main__.Stack object at 0x7f3ac8cb9970>

# %% [markdown]
# ## 2. Another Stack Class

# %%
class Stack2:
     def __init__(self):
          self.items = []

     def is_empty(self):
          return self.items == []

     def push(self, item):
          self.items.insert(0, item)

     def pop(self):
          return self.items.pop(0)

     def peek(self):
          return self.items[0]

     def size(self):
          return len(self.items)

     def pop_all(self):
          self.items.clear()

# %%
import time
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
sizes = list(range(100,10000,100))

# %%
sizes
# Out:
# [100,
#  200,
#  300,
#  400,
#  500,
#  600,
#  700,
#  800,
#  900,
#  1000,
#  1100,
#  1200,
#  1300,
#  1400,
#  1500,
#  1600,
#  1700,
#  1800,
#  1900,
#  2000,
#  2100,
#  2200,
#  2300,
#  2400,
#  2500,
#  2600,
#  2700,
#  2800,
#  2900,
#  3000,
#  3100,
#  3200,
#  3300,
#  3400,
#  3500,
#  3600,
#  3700,
#  3800,
#  3900,
#  4000,
#  4100,
#  4200,
#  4300,
#  4400,
#  4500,
#  4600,
#  4700,
#  4800,
#  4900,
#  5000,
#  5100,
#  5200,
#  5300,
#  5400,
#  5500,
#  5600,
#  5700,
#  5800,
#  5900,
#  6000,
#  6100,
#  6200,
#  6300,
#  6400,
#  6500,
#  6600,
#  6700,
#  6800,
#  6900,
#  7000,
#  7100,
#  7200,
#  7300,
#  7400,
#  7500,
#  7600,
#  7700,
#  7800,
#  7900,
#  8000,
#  8100,
#  8200,
#  8300,
#  8400,
#  8500,
#  8600,
#  8700,
#  8800,
#  8900,
#  9000,
#  9100,
#  9200,
#  9300,
#  9400,
#  9500,
#  9600,
#  9700,
#  9800,
#  9900]

# %%
def StackCompare(stack):
    timelist = []
    for size in sizes:
        thelist = list(range(size))
        start = time.time()
        stack.push(size)
        end = time.time()
        elapsed = end - start
        timelist.append(elapsed)
        if size % 100000 == 0:
            print("progress {}".format(size))
    plt.plot(sizes[:len(timelist)],timelist)
    return timelist

# %%
s = Stack()

# %%
StackTimes = StackCompare(s)

# %%
s2 = Stack2()
StackTimes2 = StackCompare(s2)

# %% [markdown]
# ## 3. Example: 문자열 뒤집기

# %%
def reverse(str):
    st = Stack()
    for i in range(len(str)):
        st.push(str[i])

    out = ""
    while not st.is_empty():
        out += st.pop()

    return out

# %%
input = "Test Seq 12345"  # 테스트 입력 문자열
answer = reverse(input)

# %%
print("Input string: ", input)
# Out:
# Input string:  Test Seq 12345

# %%
print("Reversed string: ", answer)
# Out:
# Reversed string:  54321 qeS tseT

# %% [markdown]
# ## 4. Example: Simple Balance Parentheses

# %%
def par_checker(symbol_string):
    s = Stack()
    balanced = True
    index = 0

    while index < len(symbol_string) and balanced:
        symbol = symbol_string[index]
        if symbol == "(":
            s.push(symbol)
        else:
            if s.is_empty():
                balanced = False
            else: s.pop()

        index = index + 1

    if balanced and s.is_empty():
        return True
    else:
        return False

# %%
print(par_checker('(())'))
# Out:
# True

# %%
print(par_checker('((()))'))
# Out:
# True

# %%
print(par_checker(')'))
# Out:
# False

# %% [markdown]
# ## 5.  Example: Divide By 2 Algorithm

# %%
def divide_by_2(dec_number):
    rem_stack = Stack()

    while dec_number > 0:
        rem = dec_number % 2
        rem_stack.push(rem)
        dec_number = dec_number // 2

    bin_string = ""
    while not rem_stack.is_empty():
        bin_string = bin_string + str(rem_stack.pop())
    return bin_string

# %%
print(divide_by_2(42))
# Out:
# 101010

# %%
print(divide_by_2(8))
# Out:
# 1000

# %%
print(divide_by_2(10))
# Out:
# 1010
